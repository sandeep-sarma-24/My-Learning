# %% [markdown]
# CA - 1 (EDA & Statistics) ;
# Name - RAQEEB SHAIKH ;
# Roll Number : RK20MPB56 ;
# Registeration Number : 12019283

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Question 1

# %%
df1 = pd.read_csv('train.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Finding Number of Null Values 

df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Average age per class 

df1['Age'].groupby(df1['Pclass']).mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
# replacing the age with the average of age of each class
# function to replace NAN values in (Age)`

def replace(col) : 
    age = col[0]
    pclass = col[1]
    
    if pd.isnull(age): 
        if pclass == 1:
            return 38
        elif pclass == 2:
            return 29
        else: 
            return 25
    else:
        return age

# %%
# replacing all the values with new values

df1['Age'] = df[['Age', 'Pclass']].apply(replace,axis=1)

# verification
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Question 2

# %%
from sklearn.datasets import load_boston

# %%
bs = load_boston()

# %%
boston_df = pd.DataFrame(bs.data,columns = bs.feature_names)

# %%
bs.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
corr = boston_df.corr()
corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# heatmap
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# Variable Correlation = The Statistical relationship between two variables to as their correlation.

# The correlation coefficient is usually represented using the symbol r, and it ranges from -1 to +1.

# A correlation coefficient quite close to 0, but either positive or negative, implies little or 
# no relationship between the two variables. A correlation coefficient close to plus 1 means a positive
# relationship between the two variables, with increases in one of the variables being associated 
# with increases in the other variable.

# A correlation coefficient close to -1 indicates a negative relationship between two variables,
# with an increase in one of the variables being associated with a decrease in the other variable. 
# A correlation coefficient can be produced for ordinal, interval or ratio level variables,
# but has little meaning for variables which are measured on a scale which is no more than nominal.

# %%
# Question 3

# %%
df3 = pd.read_csv("iris.csv")
df3.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Question 4

# %%
df2 = pd.read_csv("train.csv")
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# There are 2 columns with missing values Age column has 177 values missing we 
# can fill it with taking the mean of each Pclass columns But in Cabin 
# column , large number of data is missing (687 out of 891 i.e 50% ) so we will 
# remove the whole column from the dataset

# %%
# Question 5

# %%
tar = bs.target

# %%
import warnings
warnings.filterwarnings("ignore")
sns.distplot(tar)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# The graph is randomly distributed

# %%
# Question 6

# %%
bank = pd.read_csv("bank.csv")
bank
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207       51.0                         60000
# 45209                 45208       71.0                         55000
# 45210                 45209       72.0                         55000
# 45211                 45210       57.0                         20000
# 45212                 45211       37.0                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
bank.isnull().mean()
# Out:
# banking marketing    0.000000
# Unnamed: 1           0.000464
# Unnamed: 2           0.000000
# Unnamed: 3           0.000022
# Unnamed: 4           0.000000
# Unnamed: 5           0.000022
# Unnamed: 6           0.000000
# Unnamed: 7           0.000022
# Unnamed: 8           0.000000
# Unnamed: 9           0.000022
# Unnamed: 10          0.000000
# Unnamed: 11          0.000022
# Unnamed: 12          0.001106
# Unnamed: 13          0.000000
# Unnamed: 14          0.000022
# Unnamed: 15          0.000022
# Unnamed: 16          0.000022
# Unnamed: 17          0.000000
# Unnamed: 18          0.000664
# dtype: float64

# %%
# there are total 3 columns which has null values and since there are null percentage
# in the data is very less so we can drop those columns as it will not effect 
# the dataset.

# %%
bank.dropna(inplace = True)

# %%
#removing the duplicates
bank.drop_duplicates(inplace = True)
