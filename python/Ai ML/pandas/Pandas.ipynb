# %%
import pandas as pd

# %%
l = [1,1,24,124,1123,123,412]
var = pd.Series(l)
print(var)
# Out:
# 0       1
# 1       1
# 2      24
# 3     124
# 4    1123
# 5     123
# 6     412
# dtype: int64

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
import pandas as pd 

exam_scores = pd.read_csv("exam_scores.csv")

# %%
exam_scores.shape # it has 1000 rows and 8 columns // Data Frame has 8000 Entries
# Out:
# (1000, 8)

# %%
exam_scores.head() # head() method shows the first five the observations to have an idea
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exam_scores.tail() # tail() method shows the last five of the observations to have an idea
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995                    none          68             77             72
# 996                    none          98             81             94
# 997                    none          67             67             67
# 998                    none          63             68             70
# 999                    none          49             57             50

# %%
exam_scores.head(10) # we can insert a number of observations in head() method to observe. 
# Same goes for the tail() method
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
# 5  female        group D          associate's degree      standard
# 6  female        group B          associate's degree  free/reduced
# 7    male        group E            some high school  free/reduced
# 8    male        group C            some high school      standard
# 9    male        group B             master's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# ...

# %%
exam_scores.dtypes # to know which column has which datatypes in their values
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
exam_scores.info() # This method will return you a concise summary about the dataframe. 
# It gives info about total observations and ranging from (0-999) in (Rows)
# It gives info about total observations and ranging from (1-8) in (Columns)
# Memory usage , their datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# test = pd.read_csv("Standard_Metropolitan_Areas_Data-data")
import os 
cwd = os.getcwd()
files = os.listdir(cwd)
print("Files in %r: %s" % (cwd, files))

test = pd.read_csv("Standard_Metropolitan_Areas_Data-data.csv")
# Out:
# Files in 'C:\\Users\\Wayne\\Desktop\\Languages\\python\\Ai ML\\pandas': ['.ipynb_checkpoints', 'exam_scores.csv', 'Movies.csv', 'Pandas+Notebook+IV.ipynb', 'Pandas+Notebook+V.ipynb', 'Pandas.ipynb', 'Pandas_Cheat_Sheet.pdf', 'Practice+Exercise+1+IPL.ipynb', 'Practice+Exercise+2+Movies.ipynb', 'sales.xlsx', 'sales_returns.xlsx', 'Standard_Metropolitan_Areas_Data-data.csv', 'upGrad Pandas.ipynb', 'weather_data.csv']

# %%
test.shape
# Out:
# (99, 10)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
exam_scores.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
# iloc == Index based selection 
exam_scores.iloc[0,0]
# Out:
# 'male'

# %%
# select 7 rows and 5th Column [0:6 ,4] : REMEMBER (Indexing starts from 0)
exam_scores.iloc[0:6,5]
# Out:
# 0    74
# 1    58
# 2    66
# 3    74
# 4    78
# 5    75
# Name: math score, dtype: int64

# %%
# Select all columns and 4th row [3,0:6]
exam_scores.iloc[3 , 0:8]
# Out:
# gender                                    female
# race/ethnicity                           group D
# parental level of education    bachelor's degree
# lunch                               free/reduced
# test preparation course                     none
# math score                                    74
# reading score                                 75
# writing score                                 73
# Name: 3, dtype: object

# %%
#Select all the rows and columns == iloc[ : , : ]
exam_scores.iloc[ : , : ]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2      male        group C                some college  free/reduced
# 3    female        group D           bachelor's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Negative Indexing in iloc[] 
exam_scores.iloc[-5: , 0:8]
# Here the negative indexing starts from 995 which is -5 from last element.
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995                    none          68             77             72
# 996                    none          98             81             94
# 997                    none          67             67             67
# 998                    none          63             68             70
# 999                    none          49             57             50

# %%
# Label Based Solution 
# Label based selection selects data based on the column or row names/index. 
# This becomes important while selecting data from a dataframe.
# loc is used for selecting data based on the data index value/name, not the numerical positions.
exam_scores.loc[0:5, ['gender', 'lunch', 'math score']]
# here the row indexes from 0-5 inclusive which is 6 elements and there is list of column names to be selected.
# Out:
#    gender         lunch  math score
# 0    male      standard          74
# 1  female      standard          58
# 2    male  free/reduced          66
# 3  female  free/reduced          74
# 4    male      standard          78
# 5  female      standard          75

# %%
# Attribute(Dot) Based selection
exam_scores.gender
# Out:
# 0        male
# 1      female
# 2        male
# 3      female
# 4        male
#         ...
# 995    female
# 996    female
# 997    female
# 998    female
# 999      male
# Name: gender, Length: 1000, dtype: object

# %%
# Dictionary(Bracket) based selection 
exam_scores['gender']
# Out:
# 0        male
# 1      female
# 2        male
# 3      female
# 4        male
#         ...
# 995    female
# 996    female
# 997    female
# 998    female
# 999      male
# Name: gender, Length: 1000, dtype: object

# %%
# Selecting multiple columns of dataframe
exam_scores[['gender', 'lunch']]
# Out:
#      gender         lunch
# 0      male      standard
# 1    female      standard
# 2      male  free/reduced
# 3    female  free/reduced
# 4      male      standard
# ..      ...           ...
# 995  female      standard
# 996  female      standard
# 997  female  free/reduced
# 998  female      standard
# 999    male  free/reduced
#
# [1000 rows x 2 columns]

# %%
# Conditional Selection (Particular data) interested then 
exam_scores[exam_scores.gender == 'male']
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group B           bachelor's degree      standard
# 2     male        group C                some college  free/reduced
# 4     male        group D                some college      standard
# 7     male        group E            some high school  free/reduced
# 8     male        group C            some high school      standard
# ..     ...            ...                         ...           ...
# 991   male        group B             master's degree      standard
# 992   male        group A           bachelor's degree      standard
# 993   male        group A                some college      standard
# 994   male        group C             master's degree      standard
# 999   male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          74             68             67
# ...

# %%
# Assigning a column or row 
# exam_scores.gender = 'female' 
# exam_scores
# it assigns gender to all females.

# %%
test
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
sample_data1 = test.loc[[3,5,7,9,13,98], ['land_area', 'work_force', 'income', 'region', 'crime_rate']]
sample_data1
# Out:
#     land_area  work_force  income  region  crime_rate
# 3        3916      1966.7   32906       2       67.38
# 5        2815      1541.9   25663       3       58.48
# 7        6794      1272.7   18221       3       64.88
# 9        4647      1032.2   14542       2       55.30
# 13        782       915.2   12591       4       63.20
# 98        654        66.9    1148       3       68.76

# %%
sample_data2 = test[test.region == 2]
sample_data2.shape
# Out:
# (25, 10)

# %%
# Summary Functions 
# info() & describe() 
exam_scores.describe()
# describe() method by default returns the summary about the numerical columns only
# Out:
#         math score  reading score  writing score
# count  1000.000000     1000.00000    1000.000000
# mean     67.128000       70.17400      68.973000
# std      14.815367       14.85599      15.109155
# min      15.000000       18.00000      10.000000
# 25%      58.000000       60.00000      59.000000
# 50%      67.000000       70.00000      69.000000
# 75%      78.000000       81.00000      80.000000
# max     100.000000      100.00000     100.000000

# %%
exam_scores.describe(include = 'object')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       654

# %%
exam_scores.describe(include = 'all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course   math score  reading score  writing score
# count                     1000  1000.000000     1000.00000    1000.000000
# ...

# %%
# We can see the above table includes the summary about both numerical and categorical column. 
# A categorical column cannot have minimum or maximum values or mean and median. 
# So the entries in these field for categorical column is 'NaN'.
# Let's see what information about the data is returned in the above table:
# count - the count of non - null entries in the particular column.For example, gender column has 1000 non - null entries.
# unique - the count of unique values in a column. Only for categorical column. For example, gender column has 2 unique values - male and female.
# top - this is also for only categorical column. This tells which category is occurring maximum number of times. For example in gender column 'female' is occurring maximum number of times.
# freq - this is again for categorical column only. This tells you the number of occurence of the category that is occurring maximum number of times in the column. For example, 'female' in gender column is occurring 502 times
# mean - the mean value of the numerical column. For example, the mean math score is 67.128
# std - This is standard deviation of the numerical column. This tells you about the variation of data. Don't worry if you don't know about it.
# min - the minimum value in the numerical column. For example, the minimum math score is 15.0
# 25% - the 25th percentile (or 1st quartile) value in the numerical column. For example, the 25th percentile value for math score is 58.0
# 50% - the 50th percentile (or 2nd quartile or the median) value in the numerical column. For example, the median math score is 67.0
# 75% - the 75th percentile (or 3rd quartile) value in the numerical column. For example, the 75th percentile value for math score is 78.0
# max - the maximum value in the numerical column. For example, the maximum math score is 100.0
# NaN values means for a particular column a particular summary value is not available. For example, for column gender ( a categorical column), 
# do not have mean value or median value as these are the properties of numerical columns only.

# %%
# We can also use describe() method on a particular column/series.
exam_scores['math score'].describe()
# Out:
# count    1000.000000
# mean       67.128000
# std        14.815367
# min        15.000000
# 25%        58.000000
# 50%        67.000000
# 75%        78.000000
# max       100.000000
# Name: math score, dtype: float64

# %%
# aggregation Fucntions give individual functions (mean(), median(), unique()).
exam_scores.mean() # only numerical columns will give the values
# Out:
# C:\Users\Wayne\AppData\Local\Temp\ipykernel_9640\1541523904.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   exam_scores.mean() # only numerical columns will give the values
# math score       67.128
# reading score    70.174
# writing score    68.973
# dtype: float64

# %%
exam_scores.gender.unique() # returns all the unique values of the column gender.
# Out:
# array(['male', 'female'], dtype=object)

# %%
# To see all the unique values and the number of times they are occuring in the dataset, 
# we have a method called value_counts()
exam_scores.gender.value_counts()
# Out:
# female    502
# male      498
# Name: gender, dtype: int64

# %%
#Sorting 
exam_scores.sort_values(by = 'math score').head()
# by default the sorting happens in ascending order and we use head so that we can limit the numbers.
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 949    male        group C                 high school  free/reduced
# 854    male        group C                 high school  free/reduced
# 891  female        group C                 high school  free/reduced
# 349    male        group B            some high school  free/reduced
# 739  female        group E            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 949                    none          15             18             10
# 854                    none          18             30             18
# 891                    none          23             31             27
# 349                    none          25             31             30
# 739                    none          25             35             38

# %%
# for descending order 
exam_scores.sort_values(by = 'math score', ascending = False).head()
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 91    male        group D          associate's degree  standard
# 776   male        group E          associate's degree  standard
# 588   male        group D                some college  standard
# 128   male        group A          associate's degree  standard
# 565   male        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 91                     none         100             94             96
# 776               completed         100            100            100
# 588               completed         100             85             91
# 128               completed         100             97             94
# 565               completed         100            100            100

# %%
test.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
test1 = test.corr()
test1
# Out:
#                 land_area  percent_city  percent_senior  physicians  \
# land_area        1.000000     -0.077320        0.092226    0.085054
# percent_city    -0.077320      1.000000       -0.250995    0.067391
# percent_senior   0.092226     -0.250995        1.000000    0.056454
# physicians       0.085054      0.067391        0.056454    1.000000
# hospital_beds    0.081034      0.052898        0.083775    0.974241
# graduates        0.088728      0.076720       -0.155695    0.049500
# work_force       0.135792      0.016011        0.035240    0.965597
# income           0.111404      0.019235        0.046073    0.976209
# region           0.292392      0.235880       -0.242811   -0.140961
# crime_rate       0.293907      0.159596       -0.177992    0.187763
#
#                 hospital_beds  graduates  work_force    income    region  \
# land_area            0.081034   0.088728    0.135792  0.111404  0.292392
# ...

# %%
test[test.region == 4].land_area[:5]
# Out:
# 4      2480
# 13      782
# 14     4226
# 18    27293
# 20     9155
# Name: land_area, dtype: int64

# %%
test4 = test[test.region == 4].crime_rate==55.64
test4
# Out:
# 4     False
# 13    False
# 14    False
# 18    False
# 20    False
# 25    False
# 33    False
# 53    False
# 54    False
# 59    False
# 67    False
# 73    False
# 74    False
# 81    False
# 84    False
# 93    False
# 94    False
# Name: crime_rate, dtype: bool

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plt.plot(test.hospital_beds, test.physicians,"o")

# %%
import matplotlib.pyplot as plt  
plt.style.use('dark_background')
test.plot(x='land_area', y='crime_rate', kind = 'line');

# %%
plt.hist(test.income)
# Out:
# (array([80.,  9.,  4.,  2.,  2.,  0.,  0.,  1.,  0.,  1.]),
#  array([  769. ,  7902.1, 15035.2, 22168.3, 29301.4, 36434.5, 43567.6,
#         50700.7, 57833.8, 64966.9, 72100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar('region', 'frequency')
# Out:
# <BarContainer object of 1 artists>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv", sep = "|",
                 header = None)
daf = pd.DataFrame(df)
daf
# Out:
#      0        1            2   3   4   5
# 0    1   Akshay  Mathematics  50  40  80
# 1    2   Mahima      English  40  33  83
# 2    3    Vikas  Mathematics  50  42  84
# 3    4  Abhinav      English  40  31  78
# 4    5   Mahima      Science  50  40  80
# 5    6   Akshay      Science  50  49  98
# 6    7  Abhinav  Mathematics  50  47  94
# 7    8    Vikas      Science  50  40  80
# 8    9  Abhinav      Science  50  47  94
# 9   10    Vikas      English  40  39  98
# 10  11   Akshay      English  40  35  88
# 11  12   Mahima  Mathematics  50  43  86

# %%
print(test["land_area"].head) # gives a Series 
print(test["land_area"].dtype)
print(test[["land_area"]]) # gives a data frame
# Out:
# <bound method NDFrame.head of 0     1384
# 1     3719
# 2     3553
# 3     3916
# 4     2480
#       ...
# 94    1511
# 95    1543
# 96    1011
# 97     813
# 98     654
# Name: land_area, Length: 99, dtype: int64>
# int64
#     land_area
# 0        1384
# 1        3719
# 2        3553
# 3        3916
# 4        2480
# ..        ...
# 94       1511
# 95       1543
# 96       1011
# 97        813
# 98        654
#
# [99 rows x 1 columns]

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df_2 = df[["month", "day", "temp", "area"]]
print(df_2.head(20))
# Out:
#    month  day  temp  area
# 0    mar  fri   8.2   0.0
# 1    oct  tue  18.0   0.0
# 2    oct  sat  14.6   0.0
# 3    mar  fri   8.3   0.0
# 4    mar  sun  11.4   0.0
# 5    aug  sun  22.2   0.0
# 6    aug  mon  24.1   0.0
# 7    aug  mon   8.0   0.0
# 8    sep  tue  13.1   0.0
# 9    sep  sat  22.8   0.0
# 10   sep  sat  17.8   0.0
# 11   sep  sat  19.3   0.0
# 12   aug  fri  17.0   0.0
# 13   sep  mon  21.3   0.0
# 14   sep  wed  26.4   0.0
# 15   sep  fri  22.9   0.0
# 16   mar  sat  15.1   0.0
# 17   oct  mon  16.7   0.0
# 18   mar  wed  15.9   0.0
# 19   apr  sat   9.3   0.0
