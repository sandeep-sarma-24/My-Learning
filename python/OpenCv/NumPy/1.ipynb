# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image # I is capital

# %%
pic = Image.open('E:/Languages/python/OpenCv/Computer-Vision-with-Python/DATA/00-puppy.jpg') 
# Right leaning Slashes is used to locate file

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic) # to change pic datatype from JPEG to NUMPY ARRAY

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr) # imshow() to create NUMPY ARRAY PIC

# %%
pic_red = pic_arr.copy() # .copy() TO COPY THE ORIGINAL ARRAY

# %%
plt.imshow(pic_red)

# %%
# R G B - RED Channel
# 0 - Full pure red, pure black - 255 no red , closer - more red
# cmap() - COLOR MAP 
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
pic_red[:,:,0]
# Out:
# array([[95, 97, 98, ..., 25, 25, 25],
#        [95, 96, 96, ..., 25, 25, 25],
#        [95, 94, 94, ..., 25, 25, 25],
#        ...,
#        [19, 20, 20, ..., 23, 24, 24],
#        [20, 20, 19, ..., 23, 24, 24],
#        [20, 19, 19, ..., 23, 24, 24]], dtype=uint8)

# %%
# R G B - Green Channel
pic_green = pic_arr.copy()
plt.imshow(pic_green[:,:,1], cmap='gray')

# %%
pic_green
# Out:
# array([[81, 83, 84, ..., 27, 27, 27],
#        [81, 82, 82, ..., 27, 27, 27],
#        [81, 80, 80, ..., 27, 27, 27],
#        ...,
#        [29, 30, 30, ..., 30, 31, 31],
#        [30, 30, 29, ..., 30, 31, 31],
#        [30, 29, 29, ..., 30, 31, 31]], dtype=uint8)

# %%
# R G B - Blue Channel
pic_blue = pic_arr.copy()
plt.imshow(pic_blue[:,:,2], cmap='gray')

# %%
pic_blue
# Out:
# array([[78, 80, 81, ..., 22, 22, 22],
#        [78, 79, 79, ..., 22, 22, 22],
#        [78, 77, 77, ..., 22, 22, 22],
#        ...,
#        [20, 21, 21, ..., 22, 23, 23],
#        [21, 21, 20, ..., 22, 23, 23],
#        [21, 20, 20, ..., 22, 23, 23]], dtype=uint8)

# %%
# RED CHANNEL 
pic_red[:,:,1] = 0
pic_red[:,:,2] = 0
plt.imshow(pic_red)

# %%
# GREEN CHANNEL
pic_green[:,:,0] = 0
pic_green[:,:,2] = 0 
plt.imshow(pic_green)

# %%
# BKUE  
pic_blue[:,:,0] = 0
pic_blue[:,:,1] = 0 
plt.imshow(pic_blue)
